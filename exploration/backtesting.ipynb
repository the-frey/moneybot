# %%
config = {
    'db': {
        'hostname': 'localhost',
        'port': 8086,
        'username': 'root',
        'password': 'root',
        'database': 'historical-poloniex'
    }
}

# %% [markdown]
# We are using [historical poloniex influxdb](https://bitbucket.org/peakrider/poloniex-ticker-history).

# %%
from influxdb import InfluxDBClient
client = InfluxDBClient(config['db']['hostname'], 
                        config['db']['port'], 
                        config['db']['username'], 
                        config['db']['password'], 
                        config['db']['database'])

# %%
class CoinStore(object):
    def __init__(self, influx_client):
        self.client = client
    def see_available_coins (self, time):
        q ='''
        select * from ticker
        where time <= '{!s}' and time > '{!s}' - 1d
        group by coin
        order by time desc 
        limit 1
        '''.format(time, time)
        result_set = client.query(q)
        coin_generator_tuples = { r[0][1]['coin']: list(r[1])[0]  
                                 for r in result_set.items() }
        return coin_generator_tuples

# %%
class Balances(object):
    # balances = { 'COIN': coin_amt }
    def __init__(self, time, balances):
        self.balances = balances
        self.time     = time
        
    def __getitem__ (self, key):
        return self.balances[key]
    
    def held_coins (self):
        return [k  for k in self.balances.keys() 
                if self.balances[k] > 0 ]
    
    def to_influx_point (self):
        return {
            'measurement': 'balance',
            'time': self.time,
            'fields': self.balances,
        }

    # self, Purchase -> Balance
    def apply_purchases (self, time, purchases, fiat='BTC'):
        new_balances = self.balances.copy()
        total_fiat_investment = sum([p.investment_fiat 
                                     for p in purchases])
        new_balances[fiat] = self.balances[fiat] - total_fiat_investment
        for coin, amount, _ in purchases:
            if coin not in new_balances:
                new_balances[coin] = 0
            new_balances[coin] += amount
        return Balances(time, new_balances)

    def estimate_value (self, charts):
        remove = []
        value = 0
        for coin, amount_held in self.balances.items():
            try:
                value += charts[coin]['close'] * amount_held
            except KeyError:
                print('Cannot find a price for ', coin)
                remove.append(coin)
        for removal in remove:
            self.balances.pop(removal)
        return value

    # Balances.from_poloniex(poloniex_client)
    def from_poloniex(poloniex_client):
        # to implement
        pass

# %%
from collections import namedtuple
Trade = namedtuple('Trade', ['coin', 'investment_fiat'])
Purchase = namedtuple('Purchase', ['coin', 'amount', 'investment_fiat'])

b = Balances('2017-01-01', {'BTC': 1})
p = [Purchase('DOGE', 10, 0.1)]
b.apply_purchases('2017-01-02', p)

# %%
class BalancesStore (object):

    def __init__ (self, influx_client):
        self.client = influx_client
    
    def add (self, balances):
        self.client.write_points([
           balances.to_influx_point() 
        ])

# %%
cs = CoinStore(client)
test_time = '2017-01-01'
charts = cs.see_available_coins(test_time)
charts
# Out:
# {'1CR': {'close': 0.000301019,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.286883,
#   'quoteVolume': None,
#   'time': '2016-12-31T13:49:26Z',
#   'volume': 5.138296946838955,
#   'weightedAverage': None},
#  'AMP': {'close': 4.125e-05,
#   'high': 4.125e-05,
#   'low': 4.058e-05,
#   'open': 4.058e-05,
#   'price_usd': 0.039003299840000005,
#   'quoteVolume': 751.19100022,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.03077565,
#   'weightedAverage': 4.096e-05},
#  'ARDR': {'close': 1.007e-05,
#   'high': 1.007e-05,
#   'low': 1.007e-05,
#   'open': 1.007e-05,
#   'price_usd': 0.00958894603,
#   'quoteVolume': 13.10088863,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00013192,
#   'weightedAverage': 1.007e-05},
#  'BCN': {'close': 5e-08,
#   'high': 5e-08,
#   'low': 5e-08,
#   'open': 5e-08,
#   'price_usd': 4.761145e-05,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 5e-08},
#  'BCY': {'close': 0.00013048,
#   'high': 0.00013048,
#   'low': 0.00013048,
#   'open': 0.00013048,
#   'price_usd': 0.12424683992000002,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.00013048},
#  'BELA': {'close': 1.246e-05,
#   'high': 1.246e-05,
#   'low': 1.246e-05,
#   'open': 1.246e-05,
#   'price_usd': 0.01186477334,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 1.246e-05},
#  'BITCNY': {'close': 0.000145651,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.13909,
#   'quoteVolume': None,
#   'time': '2016-12-31T09:04:13Z',
#   'volume': 3.340475159968366,
#   'weightedAverage': None},
#  'BITS': {'close': 6.83824e-06,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.00654932,
#   'quoteVolume': None,
#   'time': '2016-12-31T17:04:08Z',
#   'volume': 0.021926404573299214,
#   'weightedAverage': None},
#  'BLK': {'close': 2.887e-05,
#   'high': 2.887e-05,
#   'low': 2.887e-05,
#   'open': 2.887e-05,
#   'price_usd': 0.027490851230000002,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 2.887e-05},
#  'BLOCK': {'close': 0.000106254,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.101597,
#   'quoteVolume': None,
#   'time': '2016-12-31T09:29:15Z',
#   'volume': 4.609007923462307,
#   'weightedAverage': None},
#  'BTC': {'close': 1,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 952.229,
#   'quoteVolume': None,
#   'time': '2016-12-31T12:54:26Z',
#   'volume': 128228.60887454593,
#   'weightedAverage': None},
#  'BTCD': {'close': 0.00348073,
#   'high': 0.00348073,
#   'low': 0.00348073,
#   'open': 0.00348073,
#   'price_usd': 3.31445204717,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.00348073},
#  'BTM': {'close': 8.159e-05,
#   'high': 8.159e-05,
#   'low': 8.159e-05,
#   'open': 8.159e-05,
#   'price_usd': 0.07769236411,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 8.159e-05},
#  'BTS': {'close': 4.06e-06,
#   'high': 4.06e-06,
#   'low': 4.05e-06,
#   'open': 4.05e-06,
#   'price_usd': 0.00385652745,
#   'quoteVolume': 7.25613484,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 2.938e-05,
#   'weightedAverage': 4.05e-06},
#  'BURST': {'close': 5.6e-07,
#   'high': 5.6e-07,
#   'low': 5.6e-07,
#   'open': 5.6e-07,
#   'price_usd': 0.0005332482400000001,
#   'quoteVolume': 154035.72639341,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.08626,
#   'weightedAverage': 5.6e-07},
#  'C2': {'close': 9.30218e-07,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.000894834,
#   'quoteVolume': None,
#   'time': '2016-12-31T23:09:10Z',
#   'volume': 0.6860980695860909,
#   'weightedAverage': None},
#  'CLAM': {'close': 0.00089238,
#   'high': 0.00089386,
#   'low': 0.00088303,
#   'open': 0.00089382,
#   'price_usd': 0.84273218729,
#   'quoteVolume': 6.07050713,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00537251,
#   'weightedAverage': 0.00088501},
#  'CURE': {'close': 3.61039e-05,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.0347074,
#   'quoteVolume': None,
#   'time': '2016-12-31T18:09:10Z',
#   'volume': 1.1754671049977814,
#   'weightedAverage': None},
#  'DASH': {'close': 0.01194368,
#   'high': 0.01194369,
#   'low': 0.0118909,
#   'open': 0.01194368,
#   'price_usd': 11.344951528900001,
#   'quoteVolume': 2.46528269,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.02937163,
#   'weightedAverage': 0.0119141},
#  'DCR': {'close': 0.00049089,
#   'high': 0.00049089,
#   'low': 0.00049089,
#   'open': 0.00049089,
#   'price_usd': 0.46743969381000006,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.00049089},
#  'DGB': {'close': 2.6e-07,
#   'high': 2.6e-07,
#   'low': 2.6e-07,
#   'open': 2.6e-07,
#   'price_usd': 0.00024757954,
#   'quoteVolume': 30353.50577411,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00789191,
#   'weightedAverage': 2.6e-07},
#  'DOGE': {'close': 2.4e-07,
#   'high': 2.4e-07,
#   'low': 2.4e-07,
#   'open': 2.4e-07,
#   'price_usd': 0.00022853495999999998,
#   'quoteVolume': 9.20917934,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 2.21e-06,
#   'weightedAverage': 2.4e-07},
#  'EMC2': {'close': 1.19e-06,
#   'high': 1.19e-06,
#   'low': 1.15e-06,
#   'open': 1.15e-06,
#   'price_usd': 0.00112363022,
#   'quoteVolume': 54358.72959301,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.06428852,
#   'weightedAverage': 1.18e-06},
#  'ETC': {'close': 0.0015305,
#   'high': 0.00153236,
#   'low': 0.00151959,
#   'open': 0.00151959,
#   'price_usd': 1.45468215414,
#   'quoteVolume': 3883.74572263,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 5.93308123,
#   'weightedAverage': 0.00152766},
#  'ETH': {'close': 0.00867595,
#   'high': 0.00869617,
#   'low': 0.00865861,
#   'open': 0.00867106,
#   'price_usd': 8.256377722820002,
#   'quoteVolume': 3105.42726555,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 26.92588437,
#   'weightedAverage': 0.00867058},
#  'EXP': {'close': 0.00019534,
#   'high': 0.0001994,
#   'low': 0.000195,
#   'open': 0.0001994,
#   'price_usd': 0.18613220263,
#   'quoteVolume': 143.40958243,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.02803345,
#   'weightedAverage': 0.00019547},
#  'FCT': {'close': 0.00309341,
#   'high': 0.00311,
#   'low': 0.00309341,
#   'open': 0.00311,
#   'price_usd': 2.95183372168,
#   'quoteVolume': 2333.68393698,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 7.23423721,
#   'weightedAverage': 0.00309992},
#  'FLDC': {'close': 1.06e-06,
#   'high': 1.06e-06,
#   'low': 1.06e-06,
#   'open': 1.06e-06,
#   'price_usd': 0.00100936274,
#   'quoteVolume': 190.26741554,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00020168,
#   'weightedAverage': 1.06e-06},
#  'FLO': {'close': 3.15e-06,
#   'high': 3.15e-06,
#   'low': 3.15e-06,
#   'open': 3.15e-06,
#   'price_usd': 0.00299952135,
#   'quoteVolume': 93.70871662,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00029518,
#   'weightedAverage': 3.15e-06},
#  'GAME': {'close': 0.00021205,
#   'high': 0.00021205,
#   'low': 0.00021202,
#   'open': 0.00021205,
#   'price_usd': 0.20189159258,
#   'quoteVolume': 59.32331103,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.01257807,
#   'weightedAverage': 0.00021202},
#  'GEO': {'close': 3.93775e-05,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.0373925,
#   'quoteVolume': None,
#   'time': '2016-12-31T05:44:16Z',
#   'volume': 1.415346927859865,
#   'weightedAverage': None},
#  'GRC': {'close': 7.6e-06,
#   'high': 7.6e-06,
#   'low': 7.6e-06,
#   'open': 7.6e-06,
#   'price_usd': 0.0072369404,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 7.6e-06},
#  'HUC': {'close': 1.365e-05,
#   'high': 1.365e-05,
#   'low': 1.365e-05,
#   'open': 1.365e-05,
#   'price_usd': 0.01299792585,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 1.365e-05},
#  'HZ': {'close': 2.00132e-07,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.000191356,
#   'quoteVolume': None,
#   'time': '2016-12-31T07:24:10Z',
#   'volume': 0.3765103785614248,
#   'weightedAverage': None},
#  'IOC': {'close': 0.000386173,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.371235,
#   'quoteVolume': None,
#   'time': '2016-12-31T18:09:13Z',
#   'volume': 8.752568109149191,
#   'weightedAverage': None},
#  'LBC': {'close': 1.125e-05,
#   'high': 1.145e-05,
#   'low': 1.125e-05,
#   'open': 1.145e-05,
#   'price_usd': 0.0108554106,
#   'quoteVolume': 12661.97810641,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.14446977,
#   'weightedAverage': 1.14e-05},
#  'LSK': {'close': 0.00015275,
#   'high': 0.00015275,
#   'low': 0.00015275,
#   'open': 0.00015275,
#   'price_usd': 0.14545297975000002,
#   'quoteVolume': 7.72092974,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00117937,
#   'weightedAverage': 0.00015275},
#  'LTBC': {'close': 1.2e-07,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.000115293,
#   'quoteVolume': None,
#   'time': '2016-12-31T18:44:13Z',
#   'volume': 0.14883817751294526,
#   'weightedAverage': None},
#  'LTC': {'close': 0.00451744,
#   'high': 0.00452978,
#   'low': 0.00451744,
#   'open': 0.00452978,
#   'price_usd': 4.30270387024,
#   'quoteVolume': 0.34191351,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00154495,
#   'weightedAverage': 0.00451856},
#  'MAID': {'close': 0.00010345,
#   'high': 0.00010345,
#   'low': 0.00010332,
#   'open': 0.00010332,
#   'price_usd': 0.09838430028,
#   'quoteVolume': 99.1965116,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.010249,
#   'weightedAverage': 0.00010332},
#  'NAUT': {'close': 4.751e-05,
#   'high': 4.752e-05,
#   'low': 4.751e-05,
#   'open': 4.752e-05,
#   'price_usd': 0.04524039979,
#   'quoteVolume': 186.13547939,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00884331,
#   'weightedAverage': 4.751e-05},
#  'NAV': {'close': 4.15e-05,
#   'high': 4.15e-05,
#   'low': 4.1e-05,
#   'open': 4.1e-05,
#   'price_usd': 0.03926992396,
#   'quoteVolume': 30014.18378743,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 1.23786165,
#   'weightedAverage': 4.124e-05},
#  'NEOS': {'close': 6.166e-05,
#   'high': 6.166e-05,
#   'low': 6.166e-05,
#   'open': 6.166e-05,
#   'price_usd': 0.058714440140000004,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 6.166e-05},
#  'NMC': {'close': 0.00024997,
#   'high': 0.00025021,
#   'low': 0.00024997,
#   'open': 0.00025021,
#   'price_usd': 0.23813342832000003,
#   'quoteVolume': 5.17056064,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00129308,
#   'weightedAverage': 0.00025008},
#  'NOBL': {'close': 7e-08,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 6.67248e-05,
#   'quoteVolume': None,
#   'time': '2016-12-31T13:44:08Z',
#   'volume': 0.1290374793180347,
#   'weightedAverage': None},
#  'NOTE': {'close': 4.07e-06,
#   'high': 4.07e-06,
#   'low': 4.07e-06,
#   'open': 4.07e-06,
#   'price_usd': 0.00387557203,
#   'quoteVolume': 90.2013,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00036711,
#   'weightedAverage': 4.07e-06},
#  'NSR': {'close': 1.6e-07,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.000152798,
#   'quoteVolume': None,
#   'time': '2016-12-31T08:29:16Z',
#   'volume': 2.050288616343146,
#   'weightedAverage': None},
#  'NXC': {'close': 1.611e-05,
#   'high': 1.611e-05,
#   'low': 1.611e-05,
#   'open': 1.611e-05,
#   'price_usd': 0.015340409190000001,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 1.611e-05},
#  'NXT': {'close': 6.17e-06,
#   'high': 6.17e-06,
#   'low': 6.17e-06,
#   'open': 6.17e-06,
#   'price_usd': 0.005875252930000001,
#   'quoteVolume': 102.74596148,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00063394,
#   'weightedAverage': 6.17e-06},
#  'OMNI': {'close': 0.00304296,
#   'high': 0.00304296,
#   'low': 0.00304296,
#   'open': 0.00304296,
#   'price_usd': 2.89759475784,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.00304296},
#  'PINK': {'close': 4.9e-07,
#   'high': 4.9e-07,
#   'low': 4.9e-07,
#   'open': 4.9e-07,
#   'price_usd': 0.00046659220999999997,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 4.9e-07},
#  'POT': {'close': 1.578e-05,
#   'high': 1.578e-05,
#   'low': 1.578e-05,
#   'open': 1.578e-05,
#   'price_usd': 0.015026173620000001,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 1.578e-05},
#  'PPC': {'close': 0.0002468,
#   'high': 0.0002468,
#   'low': 0.0002468,
#   'open': 0.0002468,
#   'price_usd': 0.23501011719999998,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.0002468},
#  'QTL': {'close': 1.20328e-05,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.0114709,
#   'quoteVolume': None,
#   'time': '2016-12-31T13:14:11Z',
#   'volume': 0.23497260023189115,
#   'weightedAverage': None},
#  'RADS': {'close': 0.000295,
#   'high': 0.000295,
#   'low': 0.000295,
#   'open': 0.000295,
#   'price_usd': 0.28090755500000003,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.000295},
#  'RBY': {'close': 0.000210571,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.200059,
#   'quoteVolume': None,
#   'time': '2016-12-31T04:34:06Z',
#   'volume': 4.782762205149481,
#   'weightedAverage': None},
#  'RDD': {'close': 2.00167e-08,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 1.91907e-05,
#   'quoteVolume': None,
#   'time': '2016-12-31T20:59:05Z',
#   'volume': 0.8584233039962065,
#   'weightedAverage': None},
#  'REP': {'close': 0.00393025,
#   'high': 0.00393025,
#   'low': 0.00392618,
#   'open': 0.00392618,
#   'price_usd': 3.74080305963,
#   'quoteVolume': 193.3625605,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.75961917,
#   'weightedAverage': 0.00392847},
#  'RIC': {'close': 8.76e-06,
#   'high': 8.76e-06,
#   'low': 8.76e-06,
#   'open': 8.76e-06,
#   'price_usd': 0.008341526040000002,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 8.76e-06},
#  'SBD': {'close': 0.00103444,
#   'high': 0.00103444,
#   'low': 0.00103444,
#   'open': 0.00103444,
#   'price_usd': 0.98502376676,
#   'quoteVolume': 8.05470432,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.0083321,
#   'weightedAverage': 0.00103444},
#  'SC': {'close': 2.4e-07,
#   'high': 2.4e-07,
#   'low': 2.4e-07,
#   'open': 2.4e-07,
#   'price_usd': 0.00022853495999999998,
#   'quoteVolume': 17402.53961261,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.0041766,
#   'weightedAverage': 2.4e-07},
#  'SDC': {'close': 0.00141298,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 1.34639,
#   'quoteVolume': None,
#   'time': '2016-12-31T14:54:17Z',
#   'volume': 92.10779615118948,
#   'weightedAverage': None},
#  'SJCX': {'close': 0.00013013,
#   'high': 0.00013013,
#   'low': 0.00013013,
#   'open': 0.00013013,
#   'price_usd': 0.12391355977000001,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.00013013},
#  'STEEM': {'close': 0.00017336,
#   'high': 0.00017337,
#   'low': 0.00017336,
#   'open': 0.00017337,
#   'price_usd': 0.16507841944,
#   'quoteVolume': 59.21836891,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.01026636,
#   'weightedAverage': 0.00017336},
#  'STR': {'close': 2.55e-06,
#   'high': 2.55e-06,
#   'low': 2.54e-06,
#   'open': 2.54e-06,
#   'price_usd': 0.00241866166,
#   'quoteVolume': 85.26410615,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.000217,
#   'weightedAverage': 2.54e-06},
#  'STRAT': {'close': 7.539e-05,
#   'high': 7.617e-05,
#   'low': 7.524e-05,
#   'open': 7.524e-05,
#   'price_usd': 0.07186472263,
#   'quoteVolume': 1421.08149205,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.10726141,
#   'weightedAverage': 7.547e-05},
#  'SYS': {'close': 9.62e-06,
#   'high': 9.64e-06,
#   'low': 9.62e-06,
#   'open': 9.64e-06,
#   'price_usd': 0.009160442979999999,
#   'quoteVolume': 152.343894,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00146575,
#   'weightedAverage': 9.62e-06},
#  'UNITY': {'close': 0.00204533,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 1.94449,
#   'quoteVolume': None,
#   'time': '2016-12-31T12:04:13Z',
#   'volume': 0.16409005960431786,
#   'weightedAverage': None},
#  'VIA': {'close': 3.459e-05,
#   'high': 3.459e-05,
#   'low': 3.455e-05,
#   'open': 3.455e-05,
#   'price_usd': 0.03292807882,
#   'quoteVolume': 3534.11621856,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.1222421,
#   'weightedAverage': 3.458e-05},
#  'VOX': {'close': 1.05887e-05,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.010057,
#   'quoteVolume': None,
#   'time': '2016-12-31T05:54:26Z',
#   'volume': 7.463785850651288,
#   'weightedAverage': None},
#  'VRC': {'close': 2.437e-05,
#   'high': 2.437e-05,
#   'low': 2.437e-05,
#   'open': 2.437e-05,
#   'price_usd': 0.02320582073,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 2.437e-05},
#  'VTC': {'close': 3.551e-05,
#   'high': 3.551e-05,
#   'low': 3.551e-05,
#   'open': 3.551e-05,
#   'price_usd': 0.033813651789999996,
#   'quoteVolume': 98.6445532,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.00350286,
#   'weightedAverage': 3.551e-05},
#  'XBC': {'close': 0.00158463,
#   'high': 0.00158463,
#   'low': 0.00158463,
#   'open': 0.00158463,
#   'price_usd': 1.5089306402700002,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 0.00158463},
#  'XCN': {'close': 1.1281e-06,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.00108381,
#   'quoteVolume': None,
#   'time': '2016-12-31T22:14:12Z',
#   'volume': 7.616009909485981,
#   'weightedAverage': None},
#  'XCP': {'close': 0.001832,
#   'high': 0.001832,
#   'low': 0.00183,
#   'open': 0.00183,
#   'price_usd': 1.74409311411,
#   'quoteVolume': 15.49880732,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.02838752,
#   'weightedAverage': 0.00183159},
#  'XDN': {'close': 9.19694e-08,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 8.75983e-05,
#   'quoteVolume': None,
#   'time': '2016-12-31T09:49:10Z',
#   'volume': 0.9165621501787135,
#   'weightedAverage': None},
#  'XEM': {'close': 3.81e-06,
#   'high': 3.81e-06,
#   'low': 3.81e-06,
#   'open': 3.81e-06,
#   'price_usd': 0.0036279924900000002,
#   'quoteVolume': 26.24671917,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.0001,
#   'weightedAverage': 3.81e-06},
#  'XMG': {'close': 1.66731e-05,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.0159203,
#   'quoteVolume': None,
#   'time': '2016-12-31T08:54:14Z',
#   'volume': 1.008535976080853,
#   'weightedAverage': None},
#  'XMR': {'close': 0.014135,
#   'high': 0.0142,
#   'low': 0.01412858,
#   'open': 0.01413692,
#   'price_usd': 13.513957789680001,
#   'quoteVolume': 274.63454654,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 3.89759377,
#   'weightedAverage': 0.01419192},
#  'XPM': {'close': 5.17e-05,
#   'high': 5.17e-05,
#   'low': 5.17e-05,
#   'open': 5.17e-05,
#   'price_usd': 0.049230239300000006,
#   'quoteVolume': 0,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0,
#   'weightedAverage': 5.17e-05},
#  'XRP': {'close': 6.8e-06,
#   'high': 6.82e-06,
#   'low': 6.79e-06,
#   'open': 6.82e-06,
#   'price_usd': 0.00646563491,
#   'quoteVolume': 7261.17321556,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 0.04937591,
#   'weightedAverage': 6.79e-06},
#  'XST': {'close': 4.64726e-06,
#   'high': None,
#   'low': None,
#   'open': None,
#   'price_usd': 0.00443758,
#   'quoteVolume': None,
#   'time': '2016-12-31T07:04:14Z',
#   'volume': 1.7604288959297636,
#   'weightedAverage': None},
#  'XVC': {'close': 3.7e-05,
#   'high': 3.9e-05,
#   'low': 3.7e-05,
#   'open': 3.9e-05,
#   'price_usd': 0.035689542920000004,
#   'quoteVolume': 32425.61124703,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 1.21540815,
#   'weightedAverage': 3.748e-05},
#  'ZEC': {'close': 0.05009997,
#   'high': 0.0502,
#   'low': 0.0498592,
#   'open': 0.05000001,
#   'price_usd': 47.60756490568,
#   'quoteVolume': 30.33087609,
#   'time': '2017-01-01T00:00:00Z',
#   'volume': 1.51642009,
#   'weightedAverage': 0.04999592}}

# %%
class Strategy (object):
    
    def __init__ (self, coinstore, initial_balances, start_time, end_time, 
                  fiat='BTC'):
        self.start_time = start_time
        self.end_time = end_time
        self.fiat = fiat
        self.coinstore = coinstore
        self.balances = initial_balances
        
    def step (self, time):
        charts = self.coinstore.see_available_coins(time)
        trades = self.buy_and_hold(charts, self.balances)
        purchases = [self.get_purchase_amounts(charts, trade) for trade in trades]
        self.balances = self.balances.apply_purchases(time, purchases)
        value = self.balances.estimate_value(charts)
        return self.balances, value

    def buy_and_hold (self, current_chart_data, current_balances, fiat='BTC'):
        if current_balances.held_coins() == [fiat]:
            # buy some stuffj
            available_coins = current_chart_data.keys()
            amount_to_invest_per_coin = current_balances[fiat] / ( len(available_coins) + 1 )
            trades = [ Trade(c, amount_to_invest_per_coin) 
                      for c in available_coins if c != fiat ]
            return trades
        # if we hold things other than BTC, hold
        # hold
        return []
    
    def get_purchase_amounts (self, current_chart_data, trade,
                          fee=0.0025):
        coin_close = current_chart_data[trade.coin]['close']
        investment = trade.investment_fiat - (trade.investment_fiat * fee)
        amount = investment / coin_close 
        return Purchase(trade.coin, amount, trade.investment_fiat)

# %%
import pandas as pd
from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

ex_start = date(2017, 3, 1)
ex_end   = date(2017, 5, 1)

strat = Strategy(
    CoinStore(client),
    Balances(ex_start, {'BTC': 1}),
    ex_start, ex_end,
)

for date in daterange(ex_start, ex_end):
    bal, val = strat.step(date)
    print(val)
# Out:
# 0.9975769230769264
# 0.9599300861168985
# 0.9405165213904021
# 0.9368310254145771
# 0.9568252644073861
# 0.9698906315077955
# 0.9872696600912488
# 1.01108336989782
# 1.0171132982899933
# 0.9949668220004273
# 1.0113874304707131
# 1.0464591989661256
# 1.076156447729286
# 1.1785568165344997
# 1.1910288151040167
# 1.2447973090223279
# 1.3449202775979592
# 1.3600712412588594
# 1.428506327127613
# 1.4903156537560365
# 1.5149861769666093
# 1.561366899739814
# 1.601583226422866
# 1.6963611774888139
# 1.7615132228483052
# 1.826343603294726
# 1.9598435206822242
# 2.128328864405041
# 2.327082833679148
# 2.218349522394537
# 2.3823878743626965
# 2.3105927407235565
# 2.3748086841347638
# 2.330138858157161
# 2.2530648003114466
# 2.331167014580166
# 2.438779691300572
# 2.2584217714191306
# 2.264117256407353
# 2.3711067993891786
# 2.3097320712784906
# 2.4158155788279383
# 2.4122201669601897
# 2.5450623032195177
# 2.608927647282222
# 2.7312336599050697
# 2.9280919907465552
# 3.1670396087363084
# 2.981873522556867
# 3.0994874713129597
# 3.148635608109599
# 2.949301762236681
# 3.026517451705114
# 2.9704974046969035
# 2.970766468679878
# 3.040060493375022
# 3.0710738837049423
# 3.059704192544048
# 3.0404774685531426
# 3.2378450660408364
# 3.4353268621466166
